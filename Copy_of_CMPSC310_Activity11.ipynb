# %% [markdown]
# <a href="https://colab.research.google.com/github/CMPSC-310-AI-Spring2023/activity11_distributions_bayes-Darius90332/blob/main/Copy_of_CMPSC310_Activity11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Activity 11: Distributions and Bayes Algorithm **

# %% [markdown]
# ## Binomial Distribution
# One observation I saw was the probability of success is set to half so our success rate is 50%
#
# we use a random method to mix up our data
#
# the output displays a graph and our number randomly generated
#
# if ran twice we never get the same order of numbers in the output

# %%
import numpy as np

n=100 # number of trials
p=0.5 # probability of success
s=100 # size
binomial = np.random.binomial(n,p,s)
print(binomial)

import matplotlib.pyplot as plt

plt.axis([0, 100, 0, 100])
plt.plot(binomial,linewidth=2, color='r')
plt.show()
# Out:
# [44 48 51 53 59 49 56 53 56 62 56 42 54 57 51 50 55 44 41 49 47 60 47 52
#  52 51 49 58 53 53 49 46 55 43 54 56 47 57 50 48 48 50 47 48 46 54 51 55
#  48 50 48 45 50 52 55 50 56 47 52 45 48 54 59 43 46 51 46 54 53 47 47 48
#  57 53 43 52 57 46 47 49 49 56 51 52 57 48 57 52 46 55 44 54 48 53 46 48
#  51 50 49 47]

# %% [markdown]
# ## Uniform Distribution
#
# This works similarly to the the top function but it is based on a pattern picked at random
#
# the max number is 10 and gives values from 1-10 with decimals
#
# returns a new uniform for each run
#
# output returns decimals

# %%
import numpy as np

uniform = np.random.uniform(low=1, high=10,size=100)
print(uniform)

import matplotlib.pyplot as plt

plt.axis([0, 100, 0, 10])
plt.plot(uniform,linewidth=2, color='r')
plt.show()
# Out:
# [4.63554717 2.96325425 6.08964887 1.89852376 8.46435926 3.59203016
#  9.38374653 2.84613078 6.19508363 5.69902255 1.0003947  8.10837277
#  3.65422766 9.63157177 3.29113041 7.30111579 4.85796746 6.87309797
#  7.15456702 7.3618495  5.90206878 3.770588   8.90968737 1.97843356
#  3.93663579 4.75833518 5.22134363 7.49109584 8.25849772 2.70909575
#  3.81868802 1.08408433 7.8961452  5.39358071 7.91354639 9.37357237
#  2.35552639 6.08767031 8.33490056 8.55097376 9.31366772 7.24466971
#  6.21867975 2.32681314 2.27875844 3.71649451 7.55271522 5.16227469
#  2.72114328 1.27730195 1.99760953 8.9920999  1.84131181 3.64073457
#  4.3501165  3.39274673 1.01445753 9.86572151 1.52940906 4.40196119
#  9.43194442 9.70092312 1.10042879 5.35881155 6.35340826 4.04893782
#  5.63216883 7.3594572  4.54104541 3.34938367 1.85178264 8.73158353
#  3.00581464 1.90171761 1.55076581 1.27125947 3.61379883 9.62587855
#  4.90385748 6.5579807  5.55406549 2.29535746 1.39040356 3.90872345
# ...

# %% [markdown]
# ## Normal Distribution
#
# this function returns signifcantly smaller numbers
#
# only returns a graph
#
# uses standard deviation

# %%
import numpy as np
mu, sigma = 0, 0.1 # mean and standard deviation
normal = np.random.normal(mu, sigma, 100)

import matplotlib.pyplot as plt

plt.axis([0, 100, 0, 1])
plt.plot(normal,linewidth=2, color='r')
plt.show()

# %% [markdown]
# ## Bayes Algorithm
#
# TODO: Add experimentation
#
# Ref: https://scikit-learn.org/stable/modules/naive_bayes.html

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB # Gaussian is normal distribution
X, y = load_iris(return_X_y=True) # https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
y_pred = gnb.predict(X_test)
print("Number of mislabeled points out of a total %d points : %d" % (X_test.shape[0], (y_test != y_pred).sum()))
